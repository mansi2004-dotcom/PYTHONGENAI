# %%
import pandas as pd

# %%
data = pd.read_csv('weight-height.csv')

# %%
data.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
data.loc[:,['Height_new']]= scaler.fit_transform(data.loc[:,['Height']])
data.loc[:,['Weight_new']]=scaler.fit_transform(data.loc[:,['Weight']])

# %%
data
# Out:
#     Weight  Height  Height_new  Weight_new
# 0       45     120   -2.011833   -1.649131
# 1       58     135   -1.225783   -0.905405
# 2       48     123   -1.854623   -1.477502
# 3       60     145   -0.701749   -0.790986
# 4       70     160    0.084301   -0.218889
# 5       78     162    0.189108    0.238788
# 6       80     163    0.241511    0.353208
# 7       90     175    0.870351    0.925304
# 8       95     182    1.237175    1.211353
# 9       78     170    0.608335    0.238788
# 10      82     176    0.922755    0.467627
# 11      95     182    1.237175    1.211353
# 12     105     175    0.870351    1.783450
# 13     100     183    1.289578    1.497401
# 14      85     170    0.608335    0.639256
# 15      78     177    0.975158    0.238788
# 16      50     140   -0.963766   -1.363083
# 17      65     159    0.031898   -0.504938
# 18      76     150   -0.439733    0.124369
# 19      87     167    0.451125    0.753675
# 20      45     129   -1.540203   -1.649131
# ...

# %%
data.drop('Weight',axis=1, inplace=True)

# %%
data
# Out:
#     Height  Height_new  Weight_new
# 0      120   -2.011833   -1.649131
# 1      135   -1.225783   -0.905405
# 2      123   -1.854623   -1.477502
# 3      145   -0.701749   -0.790986
# 4      160    0.084301   -0.218889
# 5      162    0.189108    0.238788
# 6      163    0.241511    0.353208
# 7      175    0.870351    0.925304
# 8      182    1.237175    1.211353
# 9      170    0.608335    0.238788
# 10     176    0.922755    0.467627
# 11     182    1.237175    1.211353
# 12     175    0.870351    1.783450
# 13     183    1.289578    1.497401
# 14     170    0.608335    0.639256
# 15     177    0.975158    0.238788
# 16     140   -0.963766   -1.363083
# 17     159    0.031898   -0.504938
# 18     150   -0.439733    0.124369
# 19     167    0.451125    0.753675
# 20     129   -1.540203   -1.649131
# 21     140   -0.963766   -1.019825
# 22     160    0.084301   -0.104470

# %%
data.drop('Height',axis=1,inplace=True)

# %%
data
# Out:
#     Height_new  Weight_new
# 0    -2.011833   -1.649131
# 1    -1.225783   -0.905405
# 2    -1.854623   -1.477502
# 3    -0.701749   -0.790986
# 4     0.084301   -0.218889
# 5     0.189108    0.238788
# 6     0.241511    0.353208
# 7     0.870351    0.925304
# 8     1.237175    1.211353
# 9     0.608335    0.238788
# 10    0.922755    0.467627
# 11    1.237175    1.211353
# 12    0.870351    1.783450
# 13    1.289578    1.497401
# 14    0.608335    0.639256
# 15    0.975158    0.238788
# 16   -0.963766   -1.363083
# 17    0.031898   -0.504938
# 18   -0.439733    0.124369
# 19    0.451125    0.753675
# 20   -1.540203   -1.649131
# 21   -0.963766   -1.019825
# 22    0.084301   -0.104470

# %%
data['height'] = data['Height']

# %%
data
# Out:
#     Weight  height  Height
# 0       45     120     120
# 1       58     135     135
# 2       48     123     123
# 3       60     145     145
# 4       70     160     160
# 5       78     162     162
# 6       80     163     163
# 7       90     175     175
# 8       95     182     182
# 9       78     170     170
# 10      82     176     176
# 11      95     182     182
# 12     105     175     175
# 13     100     183     183
# 14      85     170     170
# 15      78     177     177
# 16      50     140     140
# 17      65     159     159
# 18      76     150     150
# 19      87     167     167
# 20      45     129     129
# 21      56     140     140
# 22      72     160     160

# %%
data.drop('Height',axis=1,inplace=True)

# %%
data
# Out:
#     Weight  height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11      95     182
# 12     105     175
# 13     100     183
# 14      85     170
# 15      78     177
# 16      50     140
# 17      65     159
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160

# %%
scaler=StandardScaler()
data.loc[:,['Weight']]= scaler.fit_transform(data.loc[:,['Weight']])
data.loc[:,['Height']]=scaler.fit_transform(data.loc[:,['Height']])

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data.Weight, y=data.Height)
plt.show()

# %%
#independent variable 
#dependent variable
x=data.Weight
y=data.Height

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3, random_state=10)

# %%
x_train
# Out:
# 13    100
# 14     85
# 3      60
# 21     56
# 6      80
# 18     76
# 10     82
# 19     87
# 22     72
# 8      95
# 16     50
# 17     65
# 0      45
# 15     78
# 4      70
# 9      78
# Name: Weight, dtype: int64
