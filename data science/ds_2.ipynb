# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,9,7,4],[5,6,8,7],[7,5,4,3]])
df
# Out:
#    0  1  2  3
# 0  1  9  7  4
# 1  5  6  8  7
# 2  7  5  4  3

# %%
df1=pd.DataFrame({"name":["sam","ram","tom"],"class":["btech","mca","bca"],"rollno":[34,56,89]})
df1
# Out:
#   name  class  rollno
# 0  sam  btech      34
# 1  ram    mca      56
# 2  tom    bca      89

# %% [markdown]
# ##### Functions

# %%
df.head(6) # agar 6 nhi hai tabh bhi print kr dega.
# Out:
#    0  1  2  3
# 0  1  9  7  4
# 1  5  6  8  7
# 2  7  5  4  3

# %%
df.tail() # by default last 5 values
# Out:
#    0  1  2  3
# 0  1  9  7  4
# 1  5  6  8  7
# 2  7  5  4  3
