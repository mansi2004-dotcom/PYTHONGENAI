# %%
# !pip install spacy nltk
# https://spacy.io/models
# https://www.geeksforgeeks.org/nlp/natural-lnguage-processing-nlp-pipeline/
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------- ------------------------ 5.0/12.8 MB 25.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 11.3/12.8 MB 28.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 23.1 MB/s  0:00:00
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nlp = spacy.load("en_core_web_sm") # lg, md, sm

# %%
text = nlp('Spacy is a free, open source python library designed specifically for advanced Natural Language Processing(NLP) in production environment . Developed by Matthew Honnibal and Ines Montani(Explosion AI) in 2015, it is built on cython to provide high-speed processing for large volumes of text')

# %%
for i in text.sents:
    print(i)
# Out:
# Spacy is a free, open source python library designed specifically for advanced Natural Language Processing(NLP) in production environment .
# Developed by Matthew Honnibal and Ines Montani(Explosion AI) in 2015, it is built on cython to provide high-speed processing for large volumes of text

# %%
t = nlp("Mr. john is very intelligent. He is 21 yrs old. He is son of josph.")

# %%
t1="Mr. john is very intelligent. He is 21 yrs old. He is son of josph."
t1.split('.')
# Out:
# ['Mr',
#  ' john is very intelligent',
#  ' He is 21 yrs old',
#  ' He is son of josph',
#  '']

# %%
for i in t.sents:
    print(i)
# Out:
# Mr. john is very intelligent.
# He is 21 yrs old.
# He is son of josph.

# %%
for i in t.sents:
    for j in i:
        print(j)
# Out:
# Mr.
# john
# is
# very
# intelligent
# .
# He
# is
# 21
# yrs
# old
# .
# He
# is
# son
# of
# josph
# .

# %%
data = nlp("My  Gmail id is coderroots@gmail.com and other id is gurminder@gmail.com and jatin123@yahoo.com")

# %%
for i in data:
    if i.like_email: # like_num, like_url
        print(i)
# Out:
# coderroots@gmail.com
# gurminder@gmail.com
# jatin123@yahoo.com

# %%
for i in t:
    print(i,"POS is", i.pos_, spacy.explain(i.pos_))
# Out:
# Mr. POS is PROPN proper noun
# john POS is PROPN proper noun
# is POS is AUX auxiliary
# very POS is ADV adverb
# intelligent POS is ADJ adjective
# . POS is PUNCT punctuation
# He POS is PRON pronoun
# is POS is AUX auxiliary
# 21 POS is NUM numeral
# yrs POS is NOUN noun
# old POS is ADJ adjective
# . POS is PUNCT punctuation
# He POS is PRON pronoun
# is POS is AUX auxiliary
# son POS is NOUN noun
# of POS is ADP adposition
# josph POS is PROPN proper noun
# . POS is PUNCT punctuation
