# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,9,7,4],[5,6,8,7],[7,5,4,3]])
df
# Out:
#    0  1  2  3
# 0  1  9  7  4
# 1  5  6  8  7
# 2  7  5  4  3

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      int64
#  1   1       3 non-null      int64
#  2   2       3 non-null      int64
#  3   3       3 non-null      int64
# dtypes: int64(4)
# memory usage: 228.0 bytes

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# iterrows isme we use forloop
# Out:
# <generator object DataFrame.iterrows at 0x0000017776F24260>

# %%
df1=pd.DataFrame({'a':[1,2,3,4],'b':[4,3,2,1],'c':[3,7,80,5]})
df1
# Out:
#    a  b   c
# 0  1  4   3
# 1  2  3   7
# 2  3  2  80
# 3  4  1   5

# %%
df2=pd.DataFrame({'a':[11,2,3,4],'b':[4,3,24,1],'c':[3,7,8,5]})
df2
# Out:
#     a   b  c
# 0  11   4  3
# 1   2   3  7
# 2   3  24  8
# 3   4   1  5

# %%
# ignore index joh hai voh index ko 0to 9 tak likhega otherwise 0to4 again 0to4.
#Axis joh hai voh column wise concate krega. if axis =1 then col, axis =0 then row .
