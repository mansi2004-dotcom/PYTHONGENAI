# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence  import pad_sequences
from tensorflow.keras.datasets import imdb


#load dataset
(x_train,y_train),(x_test, y_test) = imdb.load_data(num_words=10000)

#Pad Sequences
x_train = pad_sequences(x_train, maxlen = 200)
x_test = pad_sequences(x_test, maxlen = 200)

#train
from tensorflow.keras.callbacks import Earlystopping,ReduceLROnPlateau

earlystop = EarlyStopping(monitor='loss',patience =5,restore_best_weights=True,verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = "loss", patience=2, factor=0.3, min_lr=1e-6,verbose=1)

#model 
model = Sequential()
model.add(input(shape=(200,)))

model.add(Embedding(input_dim = 10000, output_dim =64))
model.add(LSTM(64))

model.add(Dense(1, activation ='sigmoid'))

#compile
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 15
#      12 x_test = pad_sequences(x_test, maxlen = 200)
#      14 #train
# ---> 15 from tensorflow.keras.callbacks import Earlystopping,ReduceLROnPlateau
#      17 earlystop = EarlyStopping(monitor='loss',patience =5,restore_best_weights=True,verbose=1)
#      18 reduce_lr = ReduceLROnPlateau(monitor = "loss", patience=2, factor=0.3, min_lr=1e-6,verbose=1)
#
# ImportError: cannot import name 'Earlystopping' from 'tensorflow.keras.callbacks' (C:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\_tf_keras\keras\callbacks\__init__.py)
