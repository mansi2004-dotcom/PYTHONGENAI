# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
fruits=["Mango","Peach","Banana","Guava","Orange"]
sales=[200,500,700,600,400]
plt.bar(x=fruits, height=sales, width=0.6)
plt.xlabel('Fruits')
plt.ylabel('Sales')
plt.show()
