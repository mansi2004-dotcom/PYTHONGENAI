# %%
import pandas as pd

# %%
s1=pd.Series([20,30,40,50,60])
s1
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64

# %%
s1.sum()
# Out:
# np.int64(200)

# %%
s1.describe()
# Out:
# count     5.000000
# mean     40.000000
# std      15.811388
# min      20.000000
# 25%      30.000000
# 50%      40.000000
# 75%      50.000000
# max      60.000000
# dtype: float64

# %%
s1.min()
# Out:
# np.int64(20)

# %%
s1.max()
# Out:
# np.int64(60)

# %%
s1.count()
# Out:
# np.int64(5)

# %%
s1.cumsum()
# Out:
# 0     20
# 1     50
# 2     90
# 3    140
# 4    200
# dtype: int64

# %%
s1.cummax()
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64

# %%
s1.cummin()
# Out:
# 0    20
# 1    20
# 2    20
# 3    20
# 4    20
# dtype: int64

# %%
s1.cumprod()
# Out:
# 0          20
# 1         600
# 2       24000
# 3     1200000
# 4    72000000
# dtype: int64
