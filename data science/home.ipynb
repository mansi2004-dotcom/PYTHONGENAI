# %%
import pandas as pd

# %%
df=pd.DataFrame({'Name':['Mansi','Tania','Pallvi','Seerat'],'Branch':['CSE','BCA','M.com','BCA'],'Age':[22,53,45,25]})
df
# Out:
#      Name Branch  Age
# 0   Mansi    CSE   22
# 1   Tania    BCA   53
# 2  Pallvi  M.com   45
# 3  Seerat    BCA   25

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   Branch  4 non-null      str
#  2   Age     4 non-null      int64
# dtypes: int64(1), str(2)
# memory usage: 228.0 bytes

# %%
df.columns
# Out:
# Index(['Name', 'Branch', 'Age'], dtype='str')

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   36.250000
# std    15.129992
# min    22.000000
# 25%    24.250000
# 50%    35.000000
# 75%    47.000000
# max    53.000000

# %%
df[df['Age']>30]
# Out:
#      Name Branch  Age
# 1   Tania    BCA   53
# 2  Pallvi  M.com   45

# %%
df[df['Branch'] =='BCA']
# Out:
#      Name Branch  Age
# 1   Tania    BCA   53
# 3  Seerat    BCA   25

# %%
df['Name'].index # to call single column
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
import numpy as np

# %%
df1=pd.DataFrame({'Name':[np.nan,'Tania','Pallvi','Seerat'],'Branch':['CSE',np.nan,'M.com','BCA'],'Age':[22,53,45,25]})
df1
# Out:
#      Name Branch  Age
# 0     NaN    CSE   22
# 1   Tania    NaN   53
# 2  Pallvi  M.com   45
# 3  Seerat    BCA   25

# %%
df1.isnull()
# Out:
#     Name  Branch    Age
# 0   True   False  False
# 1  False    True  False
# 2  False   False  False
# 3  False   False  False

# %%
df1.isnull().sum()
# Out:
# Name      1
# Branch    1
# Age       0
# dtype: int64

# %%
df1.Name
# Out:
# 0       NaN
# 1     Tania
# 2    Pallvi
# 3    Seerat
# Name: Name, dtype: str

# %%
df1.Branch
# Out:
# 0      CSE
# 1      NaN
# 2    M.com
# 3      BCA
# Name: Branch, dtype: str

# %%
df1[df1.Name.isnull()]
# Out:
#   Name Branch  Age
# 0  NaN    CSE   22

# %%
df1[df1.Branch.isnull()]
# Out:
#     Name Branch  Age
# 1  Tania    NaN   53

# %%
df1['Age'].mode()
# Out:
# 0    22
# 1    25
# 2    45
# 3    53
# Name: Age, dtype: int64

# %%
df1['Age'].mean()
# Out:
# np.float64(36.25)

# %%
df1['Branch'].index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df1.head()
# Out:
#      Name Branch  Age
# 0     NaN    CSE   22
# 1   Tania    NaN   53
# 2  Pallvi  M.com   45
# 3  Seerat    BCA   25

# %%
df1.head(2)
# Out:
#     Name Branch  Age
# 0    NaN    CSE   22
# 1  Tania    NaN   53

# %%
df1.columns
# Out:
# Index(['Name', 'Branch', 'Age'], dtype='str')

# %%
list(df1.Name)
# Out:
# [nan, 'Tania', 'Pallvi', 'Seerat']

# %%
df1.columns[:2]
# Out:
# Index(['Name', 'Branch'], dtype='str')

# %%
df1[['Name','Age']]
# Out:
#      Name  Age
# 0     NaN   22
# 1   Tania   53
# 2  Pallvi   45
# 3  Seerat   25

# %%
df1['Age'].mean()
# Out:
# np.float64(36.25)

# %%
df1.sort_values(by='Age')
# Out:
#      Name Branch  Age
# 0     NaN    CSE   22
# 3  Seerat    BCA   25
# 2  Pallvi  M.com   45
# 1   Tania    NaN   53

# %%
df1.size
# Out:
# 12

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df1.Age.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df1.loc[:,'Branch']
# Out:
# 0      CSE
# 1      NaN
# 2    M.com
# 3      BCA
# Name: Branch, dtype: str

# %%
df1.iloc[0:2]
# Out:
#     Name Branch  Age
# 0    NaN    CSE   22
# 1  Tania    NaN   53

# %%
df1.values
# Out:
# array([[nan, 'CSE', 22],
#        ['Tania', nan, 53],
#        ['Pallvi', 'M.com', 45],
#        ['Seerat', 'BCA', 25]], dtype=object)

# %%
df1.describe()
# Out:
#              Age
# count   4.000000
# mean   36.250000
# std    15.129992
# min    22.000000
# 25%    24.250000
# 50%    35.000000
# 75%    47.000000
# max    53.000000

# %%
df1['Age'].min()
# Out:
# np.int64(22)

# %%
df1['Age'].max()
# Out:
# np.int64(53)

# %%
df1.Age.sum()
# Out:
# np.int64(145)

# %%
df1.fillna('Mansi').Name
# Out:
# 0     Mansi
# 1     Tania
# 2    Pallvi
# 3    Seerat
# Name: Name, dtype: str
