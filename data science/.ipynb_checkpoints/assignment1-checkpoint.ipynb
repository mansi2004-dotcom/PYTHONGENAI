# %%
import pandas as pd

# %%
#1.
data=pd.Series([100,200,300,400],index=['x','y','z','w'])
data.loc['y']
# Out:
# np.int64(200)

# %%
#2.
data.iloc[1]
# Out:
# np.int64(200)

# %%
# 4.
data.iloc[-1]
# Out:
# np.int64(400)

# %%
#3.
data.loc[['x','w']]
# Out:
# x    100
# w    400
# dtype: int64

# %%
#5.
data.loc['y':'z']
# Out:
# y    200
# z    300
# dtype: int64

# %%
#6.
dta = pd.Series([22,45,21,76,33,78], index=[1,2,3,4,5,6])
dta.loc[2]
# Out:
# np.int64(45)

# %%
#6.
dta.iloc[2]
# Out:
# np.int64(21)
