# %%
import pandas as pd

# %%
# 1.
df=pd.read_csv('neet_data.csv')
df.columns
# Out:
# Index(['created_at', 'retweet_count', 'source', 'user_id', 'user_name',
#        'user_description', 'user_follower_count', 'user_friends_count',
#        'user_location', 'user_verified', 'user_url', 'tweet',
#        'length_of_tweet'],
#       dtype='str')

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  str
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  str
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  str
#  5   user_description     36510 non-null  str
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  str
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   str
#  11  tweet                47381 non-null  str
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), str(7)
# memory usage: 4.4 MB

# %%
df.shape
# Out:
# (47381, 13)

# %%
#2.
df.sort_values(by='retweet_count', ascending=False)
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 47347  2020-10-30 15:48:45              0        WordPress.com
# 47348  2020-10-30 15:48:43              0        WordPress.com
# 47349  2020-10-30 15:48:42              0        WordPress.com
# 47351  2020-10-30 15:46:53              0      Twitter Web App
# 47332  2020-10-30 15:53:51              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
#3.
df.loc[df['retweet_count'] == df['retweet_count'].max(), ['source','user_name','tweet','created_at','user_url']]
# Out:
#                    source                             user_name  \
# 32860  Twitter for iPhone  \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
#
#                                                    tweet           created_at  \
# 32860  RT @JoeBiden: America, I\xe2\x80\x99m honored ...  2020-11-08 05:30:01
#
#                       user_url
# 32860  https://t.co/cHZdP4uOdu

# %%
#4.
top10 = df.sort_values(by='retweet_count', ascending=False).head(10)
top10['retweet_count'].sum()
# Out:
# np.int64(2652225)

# %%
#5.
df[df['source'] == 'Twitter for Android'].shape
# Out:
# (28850, 13)

# %%
#6.
df.loc[df['user_follower_count'] == df['user_follower_count'].max(),['user_name','user_location']]
# Out:
#       user_name user_location
# 44355      NDTV         India
# 44367      NDTV         India
# 44424      NDTV         India
# 44436      NDTV         India

# %%
#7.
result=df['user_follower_count']/df['user_friends_count']

# %%
result
# Out:
# 0        0.077778
# 1        0.770819
# 2        0.281343
# 3        0.314775
# 4        0.083333
#            ...
# 47376    0.495127
# 47377    0.030504
# 47378    1.000000
# 47379    0.106952
# 47380    0.355556
# Length: 47381, dtype: float64

# %%
#7.
df.insert(6,column ='follower_friends_ratio',value=result)

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.drop('follower_friends_ratio',axis=1,inplace=True)

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.drop('followers_friends_ratio',axis=1,inplace=True)

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
#8.
df.isnull().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description          10871
# followers_friend_ratio      147
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# dtype: int64

# %%
#9.
df['user_description'] = df['user_description'].fillna(df['tweet'])

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df['user_description'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# created_at                 0
# retweet_count              0
# source                    19
# user_id                    0
# user_name                  1
# user_description           0
# user_follower_count        0
# user_friends_count         0
# user_location          21134
# user_verified              0
# user_url               38101
# tweet                      0
# length_of_tweet            0
# dtype: int64

# %%
df.drop('user_location',axis=1, inplace=True)

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.insert(3,column='is_allow', value='True')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9436\231480145.py in ?()
# ----> 1 df.insert(3,column='is_allow', value='True')
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5617                 "'self.flags.allows_duplicate_labels' is False."
#    5618             )
#    5619         if not allow_duplicates and column in self.columns:
#    5620             # Should this be a different kind of error??
# -> 5621             raise ValueError(f"cannot insert {column}, already exists")
#    5622         if not is_integer(loc):
#    5623             raise TypeError("loc must be int")
#    5624         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert is_allow, already exists

# %%
df
# Out:
#                 created_at  retweet_count               source is_allow  \
# 0      2020-10-31 14:10:28            141  Twitter for Android     True
# 1      2020-10-31 14:10:11              1   Twitter for iPhone     True
# 2      2020-10-31 14:09:48            141      Twitter Web App     True
# 3      2020-10-31 14:09:41            141  Twitter for Android     True
# 4      2020-10-31 14:09:22              0  Twitter for Android     True
# ...                    ...            ...                  ...      ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android     True
# 47377  2020-10-30 15:29:35           1700  Twitter for Android     True
# 47378  2020-10-30 15:28:59            167  Twitter for Android     True
# 47379  2020-10-30 15:28:37            270  Twitter for Android     True
# 47380  2020-10-30 15:28:14              0  Twitter for Android     True
#
#                    user_id               user_name  \
# ...

# %%
df['tweet'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.drop('tweet',axis=1)
# Out:
#                 created_at  retweet_count               source is_allow  \
# 0      2020-10-31 14:10:28            141  Twitter for Android     True
# 1      2020-10-31 14:10:11              1   Twitter for iPhone     True
# 2      2020-10-31 14:09:48            141      Twitter Web App     True
# 3      2020-10-31 14:09:41            141  Twitter for Android     True
# 4      2020-10-31 14:09:22              0  Twitter for Android     True
# ...                    ...            ...                  ...      ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android     True
# 47377  2020-10-30 15:29:35           1700  Twitter for Android     True
# 47378  2020-10-30 15:28:59            167  Twitter for Android     True
# 47379  2020-10-30 15:28:37            270  Twitter for Android     True
# 47380  2020-10-30 15:28:14              0  Twitter for Android     True
#
#                    user_id               user_name  \
# ...
