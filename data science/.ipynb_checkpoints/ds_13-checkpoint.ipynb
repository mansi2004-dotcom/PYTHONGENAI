# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'Name':['Sourav','Priya','Mansi','Mehak','Isha','Rohan'], 'class':['btech','mca','bcom','mcom','btech','bca'],'rollno':[34,23,11,10,67,89]})
df
# Out:
#      Name  class  rollno
# 0  Sourav  btech      34
# 1   Priya    mca      23
# 2   Mansi   bcom      11
# 3   Mehak   mcom      10
# 4    Isha  btech      67
# 5   Rohan    bca      89

# %%
df.loc[:,'class'].str.capitalize()
# Out:
# 0    Btech
# 1      Mca
# 2     Bcom
# 3     Mcom
# 4    Btech
# 5      Bca
# Name: class, dtype: str

# %%
df.loc[:,'rollno'] = df.loc[:,'rollno']+2

# %%
df
# Out:
#      Name  class  rollno
# 0  Sourav  btech      38
# 1   Priya    mca      27
# 2   Mansi   bcom      15
# 3   Mehak   mcom      14
# 4    Isha  btech      71
# 5   Rohan    bca      93

# %%
def funcCap(text):
    return text.capitalize()

# %%
df.loc[:,'class']=df.loc[:,'class'].apply(funcCap) # series

# %%
df
# Out:
#      Name  class  rollno
# 0  Sourav  Btech      38
# 1   Priya    Mca      27
# 2   Mansi   Bcom      15
# 3   Mehak   Mcom      14
# 4    Isha  Btech      71
# 5   Rohan    Bca      93

# %%
df.map(lambda x: str(x)+' hi')
# Out:
#         Name     class rollno
# 0  Sourav hi  Btech hi  38 hi
# 1   Priya hi    Mca hi  27 hi
# 2   Mansi hi   Bcom hi  15 hi
# 3   Mehak hi   Mcom hi  14 hi
# 4    Isha hi  Btech hi  71 hi
# 5   Rohan hi    Bca hi  93 hi

# %%
df.applymap(lambda x: str(x)+' hi')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1568\2208046189.py in ?()
# ----> 1 df.applymap(lambda x: str(x)+' hi')
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'applymap'

# %%
data=pd.read_csv('Titanic_Dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.Survived.value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
data.Survived = data.Survived.map({0:'Not Survived',1:'Survived'})

# %%
data
# Out:
#      PassengerId      Survived  Pclass  \
# 0            892  Not Survived       3
# 1            893      Survived       3
# 2            894  Not Survived       2
# 3            895  Not Survived       3
# 4            896      Survived       3
# ..           ...           ...     ...
# 413         1305  Not Survived       3
# 414         1306      Survived       1
# 415         1307  Not Survived       3
# 416         1308  Not Survived       3
# 417         1309  Not Survived       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
pd.get_dummies(data.Pclass, dtype='int')
# Out:
#      1  2  3
# 0    0  0  1
# 1    0  0  1
# 2    0  1  0
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 413  0  0  1
# 414  1  0  0
# 415  0  0  1
# 416  0  0  1
# 417  0  0  1
#
# [418 rows x 3 columns]

# %%
data.loc[:,[1,2,3]]=pd.get_dummies(data.Pclass, dtype='int')

# %%
data
# Out:
#      PassengerId      Survived  Pclass  \
# 0            892  Not Survived       3
# 1            893      Survived       3
# 2            894  Not Survived       2
# 3            895  Not Survived       3
# 4            896      Survived       3
# ..           ...           ...     ...
# 413         1305  Not Survived       3
# 414         1306      Survived       1
# 415         1307  Not Survived       3
# 416         1308  Not Survived       3
# 417         1309  Not Survived       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.rename(columns={1:'Pclass1',2:'Pclass2',3:'Pclass3'}, inplace=True)

# %%
data
# Out:
#      PassengerId      Survived  Pclass  \
# 0            892  Not Survived       3
# 1            893      Survived       3
# 2            894  Not Survived       2
# 3            895  Not Survived       3
# 4            896      Survived       3
# ..           ...           ...     ...
# 413         1305  Not Survived       3
# 414         1306      Survived       1
# 415         1307  Not Survived       3
# 416         1308  Not Survived       3
# 417         1309  Not Survived       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
