# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('titanic_dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.shape
# Out:
# (418, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    str
#  4   Sex          418 non-null    str
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    str
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     str
#  11  Embarked     418 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 39.3 KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(30.272590361445783)

# %%
df['Age'].sum()
# Out:
# np.float64(10050.5)

# %%
df['Age'].max()
# Out:
# np.float64(76.0)

# %%
df['Age'].min()
# Out:
# np.float64(0.17)

# %%
df.Name[:10]
# Out:
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                      Svensson, Mr. Johan Cervin
# 6                            Connolly, Miss. Kate
# 7                    Caldwell, Mr. Albert Francis
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9                         Davies, Mr. John Samuel
# Name: Name, dtype: str

# %%
new=df.Name.str.split(',').str[1].str.split('.').str[0].str.strip()

# %%
new
# Out:
# 0          Mr
# 1         Mrs
# 2          Mr
# 3          Mr
# 4         Mrs
#         ...
# 413        Mr
# 414      Dona
# 415        Mr
# 416        Mr
# 417    Master
# Name: Name, Length: 418, dtype: object

# %%
df.insert(6,column='start',value=new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1988\2750384370.py in ?()
# ----> 1 df.insert(6,column='start',value=new)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5617                 "'self.flags.allows_duplicate_labels' is False."
#    5618             )
#    5619         if not allow_duplicates and column in self.columns:
#    5620             # Should this be a different kind of error??
# -> 5621             raise ValueError(f"cannot insert {column}, already exists")
#    5622         if not is_integer(loc):
#    5623             raise TypeError("loc must be int")
#    5624         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert start, already exists

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age start  SibSp  \
# 0                              Kelly, Mr. James    male  34.5    Mr      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0   Mrs      1
# 2                     Myles, Mr. Thomas Francis    male  62.0    Mr      0
# 3                              Wirz, Mr. Albert    male  27.0    Mr      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0   Mrs      1
#
#    Parch   Ticket     Fare Embarked
# 0      0   330911   7.8292        Q
# 1      0   363272   7.0000        S
# 2      0   240276   9.6875        Q
# 3      0   315154   8.6625        S
# 4      1  3101298  12.2875        S

# %%
Mr_df=df[df.loc[:,'start']=='Mr']

# %%
Mr_df
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 406         1298         0       2     Ware, Mr. William Jeffery  male  23.0
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
#
# ...

# %%
Mrs_df=df[df.loc[:,'start']=='Mrs']

# %%
Mrs_df
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 8            900         1       3
# 12           904         1       1
# 14           906         1       1
# ..           ...       ...     ...
# 383         1275         1       3
# 391         1283         1       1
# 395         1287         1       1
# 397         1289         1       1
# 411         1303         1       1
#
#                                                   Name     Sex   Age start  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0   Mrs
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0   Mrs
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0   Mrs
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0   Mrs
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0   Mrs
# ..                                                 ...     ...   ...   ...
# ...

# %%
Mr_age_mean=Mr_df.Age.mean()

# %%
Mr_age_mean
# Out:
# np.float64(32.0)

# %%
Mr_df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            57
# start           0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
Mr_df[Mr_df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 10           902         0       3                        Ilieff, Mr. Ylio
# 29           921         0       3                       Samaan, Mr. Elias
# 39           931         0       3                           Hee, Mr. Ling
# 41           933         0       1             Franklin, Mr. Thomas Parham
# 47           939         0       3                Shaughnessy, Mr. Patrick
# 54           946         0       2       Mangiavacchi, Mr. Serafino Emilio
# 58           950         0       3               Davison, Mr. Thomas Henry
# 76           968         0       3                        Miles, Mr. Frank
# 83           975         0       3                    Demetri, Mr. Marinko
# 84           976         0       2                   Lamb, Mr. John Joseph
# 85           977         0       3                      Khalil, Mr. Betros
# ...

# %%
mr_index=Mr_df[Mr_df.Age.isnull()].index

# %%
mr_index
# Out:
# Index([ 10,  29,  39,  41,  47,  54,  58,  76,  83,  84,  85,  91,  93, 102,
#        107, 108, 116, 121, 124, 133, 146, 148, 151, 163, 170, 173, 183, 191,
#        205, 211, 219, 233, 243, 255, 256, 265, 266, 267, 271, 274, 286, 288,
#        289, 290, 292, 297, 301, 312, 332, 342, 357, 358, 366, 380, 384, 413,
#        416],
#       dtype='int64')

# %%
df.loc[mr_index,'Age']=Mr_age_mean

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            29
# start           0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
Mrs_df_index=Mrs_df[Mrs_df.Age.isnull()].index

# %%
Mrs_df_index
# Out:
# Index([22, 33, 65, 132, 168, 199, 225, 249, 365, 382], dtype='int64')

# %%
mrs_mean=Mrs_df.Age.mean()

# %%
mrs_mean
# Out:
# np.float64(38.903225806451616)

# %%
df.loc[Mrs_df_index,'Age']=mrs_mean

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            19
# start           0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
miss_df=df[df.loc[:,'start']=='Miss']

# %%
miss_df
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 6            898         1       3             Connolly, Miss. Kate  female
# 18           910         1       3     Ilmakangas, Miss. Ida Livija  female
# 26           918         1       1     Ostby, Miss. Helene Ragnhild  female
# 36           928         1       3              Roth, Miss. Sarah A  female
# 37           929         1       3               Cacic, Miss. Manda  female
# ..           ...       ...     ...                              ...     ...
# 402         1294         1       1   Gibson, Miss. Dorothy Winifred  female
# 408         1300         1       3  Riordan, Miss. Johanna Hannah""  female
# 409         1301         1       3        Peacock, Miss. Treasteall  female
# 410         1302         1       3           Naughton, Miss. Hannah  female
# 412         1304         1       3   Henriksson, Miss. Jenny Lovisa  female
#
# ...

# %%
miss_mean=miss_df.Age.mean()

# %%
miss_mean
# Out:
# np.float64(21.774843750000002)

# %%
miss_index=miss_df[miss_df.Age.isnull()].index

# %%
miss_index
# Out:
# Index([36, 111, 127, 160, 188, 200, 216, 227, 268, 273, 282, 304, 408, 410], dtype='int64')

# %%
df.loc[miss_index,'Age']= miss_mean

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            5
# start          0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
master_df=df[df.loc[:,'start']=='Master']

# %%
master_df
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 21           913         0       3                  Olsen, Master. Artur Karl
# 55           947         0       3                       Rice, Master. Albert
# 64           956         0       1                Ryerson, Master. John Borie
# 80           972         0       3                       Boulos, Master. Akar
# 89           981         0       2                Wells, Master. Ralph Lester
# 154         1046         0       3               Asplund, Master. Filip Oscar
# 161         1053         0       3             Touma, Master. Georges Youssef
# 192         1084         0       3          van Billiard, Master. Walter John
# 194         1086         0       2              Drew, Master. Marshall Brines
# 196         1088         0       1            Spedden, Master. Robert Douglas
# 201         1093         0       3    Danbom, Master. Gilbert Sigvard Emanuel
# ...

# %%
master_df.Age.isnull().sum()
# Out:
# np.int64(4)

# %%
master_mean=master_df.Age.mean()

# %%
master_mean
# Out:
# np.float64(7.406470588235294)

# %%
master_index=master_df.loc[:,'start'].index

# %%
master_index
# Out:
# Index([ 21,  55,  64,  80,  89, 154, 161, 192, 194, 196, 201, 244, 281, 307,
#        339, 344, 360, 379, 389, 392, 417],
#       dtype='int64')

# %%
df.loc[master_index,'Age']= master_mean

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            1
# start          0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
dona_df=df[df.loc[:,'start']=='dona']

# %%
dona_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex        Age start  \
# 0                                Kelly, Mr. James    male  34.500000  dona
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.000000  dona
# 2                       Myles, Mr. Thomas Francis    male  62.000000  dona
# 3                                Wirz, Mr. Albert    male  27.000000  dona
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.000000  dona
# ..                                            ...     ...        ...   ...
# ...

# %%
dona_df.Age.isnull().sum()
# Out:
# np.int64(1)

# %%
dona_index=dona_df.loc[:,'start'].index

# %%
dona_index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
dona_mean=dona_df.Age.mean()

# %%
dona_mean
# Out:
# np.float64(30.211045450641386)

# %%
df.loc[dona_index,'Age']=dona_mean

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# start          0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
df.drop('Fare',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex        Age start  \
# 0                                Kelly, Mr. James    male  30.211045  dona
# 1                Wilkes, Mrs. James (Ellen Needs)  female  30.211045  dona
# 2                       Myles, Mr. Thomas Francis    male  30.211045  dona
# 3                                Wirz, Mr. Albert    male  30.211045  dona
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  30.211045  dona
# ..                                            ...     ...        ...   ...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df.loc['master_df',:]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
# ...
