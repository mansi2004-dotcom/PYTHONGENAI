# %%
import pandas as pd

# %%
df=pd.read_csv('neet_data.csv')

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.isnull().sum()
# Out:
# created_at                 0
# retweet_count              0
# source                    19
# user_id                    0
# user_name                  1
# user_description       10871
# user_follower_count        0
# user_friends_count         0
# user_location          21134
# user_verified              0
# user_url               38101
# tweet                      0
# length_of_tweet            0
# dtype: int64

# %%
df[df.source.isnull()]
# Out:
#                 created_at  retweet_count source              user_id  \
# 7159   2020-10-29 04:11:11              1    NaN  1281299996831150080
# 11548  2020-10-27 22:42:36              1    NaN  1321204725623230464
# 11829  2020-10-27 17:32:36              5    NaN  1313328500686815233
# 11839  2020-10-27 17:29:21              5    NaN  1317532067987480576
# 24180  2020-10-30 06:58:06              4    NaN  1311522988869574657
# 27852  2020-10-29 04:11:11              1    NaN  1281299996831150080
# 32503  2020-11-08 08:08:46              1    NaN  1294184927433560064
# 33016  2020-11-08 03:37:00              1    NaN  1295715136141963267
# 34115  2020-11-07 07:59:26              1    NaN  1295715136141963267
# 34312  2020-11-07 05:04:51              1    NaN  1295715136141963267
# 34329  2020-11-07 04:47:17              1    NaN  1295715136141963267
# 34441  2020-11-07 03:14:42              1    NaN  1295715136141963267
# ...

# %%
df[df.loc[:,'source'] == 'Twitter for Android']
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# 5      2020-10-31 14:07:29             80  Twitter for Android
# 6      2020-10-31 14:06:34            141  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 3      1085818329816883201                 The Rus
# 4      1227501071490113537            Sakshi Yadav
# ...

# %%
df[df.loc[:,'retweet_count'] == 141]
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 6      2020-10-31 14:06:34            141  Twitter for Android
# 8      2020-10-31 14:06:06            141  Twitter for Android
# ...                    ...            ...                  ...
# 32914  2020-11-08 05:11:38            141  Twitter for Android
# 32915  2020-11-08 05:11:26            141  Twitter for Android
# 32917  2020-11-08 05:10:36            141  Twitter for Android
# 39554  2020-11-04 02:31:36            141      Twitter Web App
# 40871  2020-11-03 04:20:55            141   Twitter for iPhone
#
#                    user_id                                          user_name  \
# 0      1250294694937915394                                               Rumi
# ...

# %%
df.loc[df['retweet_count'] == df['retweet_count'].max(),['user_follower_count','user_friends_count']]
# Out:
#        user_follower_count  user_friends_count
# 32860                   62                 115

# %%
df.loc[df['user_follower_count'] == df['user_follower_count'].max(),['user_name','source']]
# Out:
#       user_name                          source
# 44355      NDTV  Twitter Media Studio - LiveCut
# 44367      NDTV  Twitter Media Studio - LiveCut
# 44424      NDTV  Twitter Media Studio - LiveCut
# 44436      NDTV  Twitter Media Studio - LiveCut

# %%
df['user_follower_count'].max()
# Out:
# np.int64(13934355)

# %%
df['retweet_count'].max()
# Out:
# np.int64(614304)

# %%
df.tail(50)
# Out:
#                 created_at  retweet_count                   source  \
# 47331  2020-10-30 15:54:27             47      Twitter for Android
# 47332  2020-10-30 15:53:51              0      Twitter for Android
# 47333  2020-10-30 15:53:11              1      Twitter for Android
# 47334  2020-10-30 15:53:05              0      Twitter for Android
# 47335  2020-10-30 15:53:04              1      Twitter for Android
# 47336  2020-10-30 15:52:53              0      Twitter for Android
# 47337  2020-10-30 15:52:18              0          Twitter Web App
# 47338  2020-10-30 15:51:44              0       Twitter for iPhone
# 47339  2020-10-30 15:50:05              0       Twitter for iPhone
# 47340  2020-10-30 15:49:57              0      Twitter for Android
# 47341  2020-10-30 15:49:39           3339      Twitter for Android
# 47342  2020-10-30 15:49:23           4913      Twitter for Android
# 47343  2020-10-30 15:49:16              0       Twitter for iPhone
# ...

# %%
df.tail()
# Out:
#                 created_at  retweet_count               source  \
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 47376  1168840190426632192             neet_fad_do
# 47377           1696615807  Yarutai - Garbage NEET
# 47378  1313330869113745413                 Raushan
# 47379  1161551282995388416               Vijaykant
# 47380  1211810532006612992                  Icarus
#
#                                         user_description  user_follower_count  \
# 47376                                     Bhola sa chora                  254
# 47377  Random person who likes drawing (but not a \nl...                   23
# ...

# %%
df.head()
# Out:
#             created_at  retweet_count               source  \
# 0  2020-10-31 14:10:28            141  Twitter for Android
# 1  2020-10-31 14:10:11              1   Twitter for iPhone
# 2  2020-10-31 14:09:48            141      Twitter Web App
# 3  2020-10-31 14:09:41            141  Twitter for Android
# 4  2020-10-31 14:09:22              0  Twitter for Android
#
#                user_id     user_name  \
# 0  1250294694937915394          Rumi
# 1             57059492    Tom Bewick
# 2           1016022678      Lemonade
# 3  1085818329816883201       The Rus
# 4  1227501071490113537  Sakshi Yadav
#
#                                     user_description  user_follower_count  \
# 0                                                NaN                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# 3                                                NaN                  147
# ...

# %%
df.isnull().sum()
# Out:
# created_at                 0
# retweet_count              0
# source                    19
# user_id                    0
# user_name                  1
# user_description       10871
# user_follower_count        0
# user_friends_count         0
# user_location          21134
# user_verified              0
# user_url               38101
# tweet                      0
# length_of_tweet            0
# dtype: int64

# %%
df.drop('user_url',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# created_at                 0
# retweet_count              0
# source                    19
# user_id                    0
# user_name                  1
# user_description       10871
# user_follower_count        0
# user_friends_count         0
# user_location          21134
# user_verified              0
# tweet                      0
# length_of_tweet            0
# dtype: int64

# %%
df.drop('user_location',axis=1,inplace=True)

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.isnull().sum()
# Out:
# created_at                 0
# retweet_count              0
# source                    19
# user_id                    0
# user_name                  1
# user_description       10871
# user_follower_count        0
# user_friends_count         0
# user_verified              0
# tweet                      0
# length_of_tweet            0
# dtype: int64

# %%
df.drop('user_description',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# created_at              0
# retweet_count           0
# source                 19
# user_id                 0
# user_name               1
# user_follower_count     0
# user_friends_count      0
# user_verified           0
# tweet                   0
# length_of_tweet         0
# dtype: int64

# %%
df[df.source.isnull()]
# Out:
#                 created_at  retweet_count source              user_id  \
# 7159   2020-10-29 04:11:11              1    NaN  1281299996831150080
# 11548  2020-10-27 22:42:36              1    NaN  1321204725623230464
# 11829  2020-10-27 17:32:36              5    NaN  1313328500686815233
# 11839  2020-10-27 17:29:21              5    NaN  1317532067987480576
# 24180  2020-10-30 06:58:06              4    NaN  1311522988869574657
# 27852  2020-10-29 04:11:11              1    NaN  1281299996831150080
# 32503  2020-11-08 08:08:46              1    NaN  1294184927433560064
# 33016  2020-11-08 03:37:00              1    NaN  1295715136141963267
# 34115  2020-11-07 07:59:26              1    NaN  1295715136141963267
# 34312  2020-11-07 05:04:51              1    NaN  1295715136141963267
# 34329  2020-11-07 04:47:17              1    NaN  1295715136141963267
# 34441  2020-11-07 03:14:42              1    NaN  1295715136141963267
# ...

# %%
df["source"] = df["source"].fillna("Unknown")

# %%
df['source']
# Out:
# 0        Twitter for Android
# 1         Twitter for iPhone
# 2            Twitter Web App
# 3        Twitter for Android
# 4        Twitter for Android
#                 ...
# 47376    Twitter for Android
# 47377    Twitter for Android
# 47378    Twitter for Android
# 47379    Twitter for Android
# 47380    Twitter for Android
# Name: source, Length: 47381, dtype: str

# %%
df['source'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.insert(3,'is_allow','True')

# %%
df
# Out:
#                 created_at  retweet_count               source is_allow  \
# 0      2020-10-31 14:10:28            141  Twitter for Android     True
# 1      2020-10-31 14:10:11              1   Twitter for iPhone     True
# 2      2020-10-31 14:09:48            141      Twitter Web App     True
# 3      2020-10-31 14:09:41            141  Twitter for Android     True
# 4      2020-10-31 14:09:22              0  Twitter for Android     True
# ...                    ...            ...                  ...      ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android     True
# 47377  2020-10-30 15:29:35           1700  Twitter for Android     True
# 47378  2020-10-30 15:28:59            167  Twitter for Android     True
# 47379  2020-10-30 15:28:37            270  Twitter for Android     True
# 47380  2020-10-30 15:28:14              0  Twitter for Android     True
#
#                    user_id               user_name  user_follower_count  \
# ...

# %%
df.drop('tweet',axis=1,inplace=True)

# %%
df
# Out:
#                 created_at  retweet_count               source is_allow  \
# 0      2020-10-31 14:10:28            141  Twitter for Android     True
# 1      2020-10-31 14:10:11              1   Twitter for iPhone     True
# 2      2020-10-31 14:09:48            141      Twitter Web App     True
# 3      2020-10-31 14:09:41            141  Twitter for Android     True
# 4      2020-10-31 14:09:22              0  Twitter for Android     True
# ...                    ...            ...                  ...      ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android     True
# 47377  2020-10-30 15:29:35           1700  Twitter for Android     True
# 47378  2020-10-30 15:28:59            167  Twitter for Android     True
# 47379  2020-10-30 15:28:37            270  Twitter for Android     True
# 47380  2020-10-30 15:28:14              0  Twitter for Android     True
#
#                    user_id               user_name  user_follower_count  \
# ...

# %%
df.loc[df['user_friends_count'] == df['user_friends_count'].max()]
# Out:
#                 created_at  retweet_count         source is_allow   user_id  \
# 37873  2020-11-04 22:19:20              0  Lithium Tech.     True  15131310
#
#                 user_name  user_follower_count  user_friends_count  \
# 37873  Whole Foods Market              4342956              490801
#
#        user_verified  length_of_tweet
# 37873           True              140

# %%
df[df.loc[:,'source'] == 'Twitter for Android'].index
# Out:
# Index([    0,     3,     4,     5,     6,     7,     8,     9,    13,    14,
#        ...
#        47367, 47369, 47370, 47371, 47375, 47376, 47377, 47378, 47379, 47380],
#       dtype='int64', length=28850)

# %%
df[df['user_name'] == 'Whole Foods Market']
# Out:
#                 created_at  retweet_count         source is_allow   user_id  \
# 37873  2020-11-04 22:19:20              0  Lithium Tech.     True  15131310
#
#                 user_name  user_follower_count  user_friends_count  \
# 37873  Whole Foods Market              4342956              490801
#
#        user_verified  length_of_tweet
# 37873           True              140

# %%
df[df.loc[:,'source'] == 'Twitter for Android'].shape
# Out:
# (28850, 13)

# %%
df.shape
# Out:
# (47381, 13)

# %%
df.loc([df[:,'retweet_count'] == 'retweet_count' & df['source'] == 'Twitter for Android'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: (slice(None, None, None), 'retweet_count')
#
# The above exception was the direct cause of the following exception:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.loc([df[:,'retweet_count'] == 'retweet_count' & df['source'] == 'Twitter for Android'])
#
# ...
