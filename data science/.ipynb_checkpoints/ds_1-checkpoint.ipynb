# %%
# !pip install pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.7 MB 6.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.7 MB 5.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.7 MB 4.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.7 MB 3.4 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.7 MB 3.1 MB/s eta 0:00:03
#    -------------- ------------------------- 3.4/9.7 MB 3.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.7 MB 2.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.7 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.7 MB 2.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.7 MB 3.0 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
s1=pd.Series([23,45,23,11,67])
s1
# Out:
# 0    23
# 1    45
# 2    23
# 3    11
# 4    67
# dtype: int64

# %%
s2=pd.Series([23,45,"hello",56.7,True])
s2
# Out:
# 0       23
# 1       45
# 2    hello
# 3     56.7
# 4     True
# dtype: object

# %% [markdown]
# ### Access

# %%
s2.loc[:]
s2
# Out:
# 0       23
# 1       45
# 2    hello
# 3     56.7
# 4     True
# dtype: object

# %%
s2.loc[:3]
s2
# Out:
# 0       23
# 1       45
# 2    hello
# 3     56.7
# 4     True
# dtype: object

# %%
s2.loc[:2]
# Out:
# 0       23
# 1       45
# 2    hello
# dtype: object

# %%
s2.iloc[:2]
# Out:
# 0    23
# 1    45
# dtype: object
